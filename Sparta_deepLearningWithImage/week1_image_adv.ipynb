# %% [markdown]
# <a href="https://colab.research.google.com/github/jmParkGit/Colab/blob/main/Sparta_deepLearningWithImage/week1_image_adv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 이미지 불러오기

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('01.jpg')
overlay_img = cv2.imread('dices.png', cv2.IMREAD_UNCHANGED)

# %% [markdown]
# ## 오버레이 이미지 만들기

# %%
overlay_img = cv2.resize(overlay_img, dsize=(150, 150))
overlay_alpha = overlay_img[:, :, 3:] / 255.0
background_alpha = 1.0 - overlay_alpha

# %% [markdown]
# ## 이미지 합성하기

# %%
#이미지 합성하기
x1 = 100
y1 = 100
x2 = x1 + 150
y2 = y1 + 150

img[y1:y2, x1:x2] = overlay_alpha * overlay_img[:, :, :3] + background_alpha * img[y1:y2, x1:x2]

print('img')
cv2_imshow(img)
# Out:
# img
# <PIL.Image.Image image mode=RGB size=640x404 at 0x7FEA453BACD0>
