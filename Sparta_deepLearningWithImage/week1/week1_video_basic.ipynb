# %% [markdown]
# <a href="https://colab.research.google.com/github/jmParkGit/Colab/blob/main/Sparta_deepLearningWithImage/week1/week1_video_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Colab에서 비디오 플레이어 하는법

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('04.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
# ## local pc에서 비디오 플레이어 하는법
# - 단, colab에서는 비디오가 아니라 이미지 리스트로 나옴.

# %%
import cv2
from google.colab.patches import cv2_imshow

cap = cv2.VideoCapture('04.mp4')

while True:
	ret, img = cap.read()

	if ret == False:
		break

	cv2_imshow(img)
	
	if cv2.waitKey(100) == ord('q'):
		break
